# %% [markdown]
# **Linear Regression**

# %%
#Predict the no. of hours the battery will last based the battery capacity
from sklearn.linear_model import LinearRegression

battery = [[2000], [3000], [7000], [9000]]
backup = [8, 12, 16, 20]
model = LinearRegression()
model.fit(battery, backup)
prediction = model.predict([[8000]])
print(prediction)
# Out:
# [18.19847328]

# %% [markdown]
# **Decision Tree**

# %%
# Loan Approval Prediction (Salary is the attribute used to predict whether the loan should be given or not)
from sklearn.tree import DecisionTreeClassifier
salary=[[20],[30],[40],[60]]
loan_status=[0,0,1,1]
model=DecisionTreeClassifier()
model.fit(salary,loan_status)
prediction=model.predict([[36]])
print(prediction)
# Out:
# [1]

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
salary=[[20],[30],[40],[60]]
loan_status=[0,0,1,1]
model=LogisticRegression()
model.fit(salary,loan_status)
prediction=model.predict([[40]])
print(prediction)
# Out:
# [1]
